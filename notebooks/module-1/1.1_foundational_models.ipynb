# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ## Initialising and invoking a model

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from dotenv import load_dotenv
import os

load_dotenv()

model = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    google_api_key=os.getenv("GOOGLE_API_KEY")
)

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model(model="gpt-5-nano")

# %%
response = model.invoke("What's the capital of the Moon?")

response
# Out:
# AIMessage(content="The Moon does not have a capital.\n\nIt's not a country, it doesn't have a government, and it has no permanent human population or cities. Therefore, it doesn't have a designated capital city like Earth's countries do.", additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019e0f01-278c-7ba3-baa0-12b7cb47d13c-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 10, 'output_tokens': 596, 'total_tokens': 606, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 544}})

# %%
print(response.content)
# Out:
# The Moon does not have a capital.
#
# It's not a country, it doesn't have a government, and it has no permanent human population or cities. Therefore, it doesn't have a designated capital city like Earth's countries do.

# %%
from pprint import pprint

pprint(response.response_metadata)
# Out:
# {'finish_reason': 'STOP',
#  'model_name': 'gemini-2.5-flash',
#  'model_provider': 'google_genai',
#  'safety_ratings': []}

# %% [markdown]
# ## Customising your Model

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from dotenv import load_dotenv
import os

load_dotenv()

model = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    google_api_key=os.getenv("GOOGLE_API_KEY"),
    temperature=1
)

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# That's a fun question!
#
# The Moon doesn't have a capital city. It's a celestial body, Earth's only natural satellite, and there are no countries, governments, cities, or permanent human settlements on it. So, there's no need for a capital.

# %% [markdown]
# ## Model Providers

# %% [markdown]
# https://docs.langchain.com/oss/python/integrations/chat

# %%
model = init_chat_model(model="claude-sonnet-4-5")

response = model.invoke("What's the capital of the Moon?")
print(response.content)

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# That's a fun question! The Moon doesn't have a capital city because it's not a country or a populated place with a government. It's a natural satellite.
#
# So, the answer is: **The Moon doesn't have a capital.**

# %% [markdown]
# ## Initialising and invoking an agent

# %%
from langchain.agents import create_agent

agent = create_agent(model=model)

# %%
agent = create_agent(model="google_genai:gemini-2.5-flash")

# %%
agent = create_agent("gpt-5-nano")

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?")]}
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='181e9d96-3886-468f-8390-31829072887d'),
#               AIMessage(content='The Moon does not have a capital.\n\nIt\'s not a country or a political entity, and there are no permanent human settlements or governments on the Moon that would designate a capital city. The concept of a "capital" only applies to human political divisions on Earth (or potentially other planets if humans establish such divisions there in the future).', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019e0f0e-fb9f-7240-9fd6-de3a59016a7f-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 10, 'output_tokens': 520, 'total_tokens': 530, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 451}})]}

# %%
print(response['messages'][-1].content)
# Out:
# The Moon does not have a capital.
#
# It's not a country or a political entity, and there are no permanent human settlements or governments on the Moon that would designate a capital city. The concept of a "capital" only applies to human political divisions on Earth (or potentially other planets if humans establish such divisions there in the future).

# %%
from langchain.messages import AIMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?"),
    AIMessage(content="The capital of the Moon is Luna City."),
    HumanMessage(content="Interesting, tell me more about Luna City")]}
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='5e5d224e-381b-41e8-8e53-319da07b6999'),
#               AIMessage(content='The capital of the Moon is Luna City.', additional_kwargs={}, response_metadata={}, id='3fdef6ad-20b8-46dc-b3ef-2c1f4e904074', tool_calls=[], invalid_tool_calls=[]),
#               HumanMessage(content='Interesting, tell me more about Luna City', additional_kwargs={}, response_metadata={}, id='a2891cc9-4669-41a6-ad52-e0a69636b3e2'),
#               AIMessage(content='Ah, Luna City! It\'s a fascinating metropolis, often considered the crown jewel of lunar colonization efforts. While its exact location has shifted in various proposals, it\'s generally envisioned as a sprawling, self-sustaining city, likely situated within a large, ancient crater near one of the lunar poles for access to water ice.\n\nHere\'s a deeper dive into what makes Luna City so remarkable:\n\n1.  **Location and Structure:**\n    *   **Strategic Placement:** Often envisioned near the lunar South Pole, like in Shackleton Crater, which offers shadowed regions rich in water ice – crucial for life support and rocket fuel.\n    *   **Underground and Domes:** To protect inhabitants from harsh solar radiation, meteoroids, and extreme temperature swings, the primary living and working areas are built deep underground, carved into the regolith or lava tubes. Massive, transparent **geodesic domes** dot the surface, offering breathtaking views of the lunar landscape and Earth, often serving as parks, agricultural zones, or recreational areas.\n    *   **Modular Design:** The city grows in a modular fashion, with standardized habitat units, power modules, and infrastructure components that can be expanded as the population grows.\n\n2.  **Purpose and Economy:**\n    *   **Research Hub:** Luna City is a global center for scientific research, from astronomy (the lack of atmosphere makes for unparalleled telescopes) to geology, physics, and astrobiology.\n    *   **Resource Extraction:** It\'s the primary hub for mining operations, extracting valuable resources like **Helium-3** (a potential fuel for future fusion reactors), titanium, silicon, and the all-important water ice.\n    *   **Spaceport and Launchpad:** Its low gravity makes it an ideal launchpad for deep-space missions, reducing the energy required to escape a gravity well. It serves as a vital waystation for journeys to Mars and beyond.\n    *   **Tourism:** High-end "space tourism" is a growing industry, with visitors coming to experience low gravity, witness Earthrise, and explore the lunar surface.\n    *   **Manufacturing:** With access to lunar resources, Luna City develops specialized manufacturing capabilities, producing components for spacecraft and other lunar infrastructure.\n\n3.  **Governance and Society:**\n    *   **International Consortium:** Luna City is typically governed by an international body, perhaps the "Lunar Consortium" or "United Lunar Council," representing various Earth nations and private corporations that contributed to its establishment.\n    *   **Diverse Population:** Its inhabitants are a melting pot of scientists, engineers, resource extractors, support staff, artists, and families from all over Earth, creating a unique lunar culture.\n    *   **High-Tech Living:** Life in Luna City is highly advanced, with sophisticated recycling systems, AI-managed infrastructure, hydroponic farms providing fresh food, and advanced medical facilities.\n    *   **Unique Culture:** A distinct "Lunarian" culture emerges, characterized by resourcefulness, a strong sense of community, a deep appreciation for Earth, and a focus on sustainability and exploration. Low-gravity sports and art forms are popular.\n\n4.  **Key Features:**\n    *   **The Nexus Dome:** Often the largest surface dome, serving as a central plaza, market, and gathering place, offering panoramic views of the lunar horizon.\n    *   **Hydroponic Gardens:** Vast, climate-controlled farms that provide fresh produce, vital for both nutrition and psychological well-being.\n    *   **Lunar Observatories:** Cutting-edge telescopes, both surface-based and radio observatories on the far side (shielded from Earth\'s radio noise), offering unprecedented views of the cosmos.\n    *   **The Earth-rise Plaza:** A dedicated viewing platform, often within a dome, where residents and tourists gather to witness the majestic Earthrise over the lunar horizon.\n\nIn essence, L ...

# %% [markdown]
# ## Streaming Output

# %%
for token, metadata in agent.stream(
    {"messages": [HumanMessage(content="Tell me all about Luna City, the capital of the Moon")]},
    stream_mode="messages"
):

    # token is a message chunk with token content
    # metadata contains which node produced the token
    
    if token.content:  # Check if there's actual content
        print(token.content, end="", flush=True)  # Print token
# Out:
# Ah, Luna City! The shining beacon of humanity's expansion beyond Earth, the bustling capital of the Moon, and a testament to ingenuity and collaboration. While still a vision in our present, let's dive into what a fully realized Luna City might be like:
#
# ## Luna City: The Lunar Metropolis
#
# **Official Name:** Luna City, sometimes colloquially referred to as "The Lunar Metropolis," "Moonbase One," or simply "The City."
#
# **Location:** While there could be multiple lunar settlements, the capital is often envisioned in a strategically vital location. A prime candidate is **Shackleton Crater** at the Moon's South Pole, due to its abundant water ice in permanently shadowed regions and near-constant sunlight on its rims for power. This allows for both resource extraction and energy generation. Other possibilities include large lava tubes for natural shielding.
#
# **Overall Concept:** Luna City is not a single dome or structure, but a sprawling, multi-tiered, interconnected complex, primarily built **underground** to protect its inhabitants from the harsh lunar environment: radiation, micrometeorites, and extreme temperature swings.
#
# ---
#
# ### I. Architecture & Infrastructure
#
# 1.  **Underground Network:** The heart of Luna City lies beneath the regolith. Vast tunnels, excavated and reinforced, connect various "districts" or modules. These modules are often designed as large, pressurized caverns or domed habitats.
# 2.  **Surface Presence:** While mostly underground, key surface structures are essential:
#     *   **Launch Pads & Spaceports:** For shuttles to Earth, orbital stations, and missions further into the solar system.
#     *   **Solar Farms:** Sprawling arrays on crater rims provide the bulk of the city's power.
#     *   **Mining Operations:** Automated drills and excavators for water ice, Helium-3, and rare lunar regolith elements.
#     *   **Observatories:** Unparalleled views of the cosmos, free from atmospheric distortion.
#     *   **Communication Arrays:** Linking Luna City to Earth and other space assets.
#     *   **Visitor Hubs:** Small, robust surface habitats for initial arrivals and acclimatization before descending into the main city.
# 3.  **Internal Layout:**
#     *   **Habitation Domes/Zones:** Each zone might house a few thousand residents, complete with residential blocks, commercial areas, parks, and recreational facilities. These are often designed with high ceilings and projected "skies" to mitigate claustrophobia.
#     *   **Biospheres:** Large, multi-story biomes replicating Earth-like ecosystems, providing fresh air, food, and psychological comfort. These are the "lungs" and "gardens" of the city.
#     *   **Industrial Zones:** Dedicated areas for manufacturing, resource processing, and life support systems, often located on the outer fringes or lower levels.
#     *   **Scientific & Research Facilities:** Laboratories for astrophysics, geology, low-gravity biology, and material science.
# 4.  **Life Support & Resources:**
#     *   **Closed-Loop Systems:** Hyper-efficient recycling of air, water, and waste is paramount. Every drop of water and every breath of air is meticulously managed.
#     *   **Hydroponics & Aquaponics:** The primary source of fresh food, grown in vertical farms within the biospheres and dedicated agricultural modules.
#     *   **Power:** Primarily solar, supplemented by small-scale fusion reactors (if Helium-3 mining is viable) or fission reactors for base load and critical systems.
#     *   **Atmosphere:** Carefully controlled Earth-like pressure and composition.
#     *   **Shielding:** The overlying regolith, lava tubes, and advanced electromagnetic shielding protect against cosmic and solar radiation.
# 5.  **Transportation:**
#     *   **Maglev Trains/Shuttles:** High-speed internal transport connecting distant districts.
#     *   **Automated Pods:** Personal transport within smaller zones.
#     *   **Low-G Vehicles:** Scooters or small, wheeled vehicles for individual mobility in wider corridors.
#     *   **Vertical Elevators/Shafts:** Connecting different underground levels and the surface.
#
# ---
#
# ### II. Governance & Economy
#
# 1.  **Governance:** Luna City is likely governed by an **International Lunar Authority (ILA)** or a similar body, perhaps a direct extension of the United Nations or a consortium of spacefaring nations and corporations. It would feature a council with representatives from major contributing nations and a democratically elected local government for its permanent residents.
# 2.  **Economy:**
#     *   **Resource Extraction:** Helium-3 (for fusion power on Earth), water ice (for rocket fuel and life support), rare earth elements, and construction materials from lunar regolith.
#     *   **Scientific Research:** A global hub for astronomy, physics, and astrobiology, generating valuable data and intellectual property.
#     *   **Tourism:** A unique, high-end destination for Earth-based tourists seeking an unparalleled experience (low-gravity sports, lunar excursions, cosmic views).
#     *   **Space Gateway:** A vital staging post for missions to Mars, the asteroid belt, and beyond, offering refueling, resupply, and maintenance services.
#     *   **Manufacturing:** Production of specialized components for spacecraft, satellites, and other space infrastructure, leveraging the low-gravity vacuum.
#     *   **Intellectual Capital:** Export of advanced technologies, engineering solutions, and expertise back to Earth.
#
# ---
#
# ### III. Daily Life in Luna City
#
# 1.  **Population:** A diverse mix of scientists, engineers, miners, service personnel, families, and entrepreneurs from every corner of Earth, forming a truly international community.
# 2.  **Gravity:** The constant 1/6th Earth gravity is a defining aspect. Residents experience a unique physical environment, affecting everything from movement to exercise and sports. Dedicated low-G gyms and recreational areas are common.
# 3.  **Environment:** While underground, the city strives for a vibrant, non-claustrophobic feel. Artificial lighting simulates daylight cycles, "sky" projections mimic Earth's heavens, and the biospheres provide lush green spaces.
# 4.  **Food:** A mix of locally grown hydroponic produce, synthesized proteins, and carefully rationed, expensive imports from Earth for special occasions.
# 5.  **Work & Leisure:** Long work shifts are balanced with ample opportunities for unique lunar leisure: zero-G gymnastics, low-G basketball, exploring simulated outdoor environments, VR experiences, and unparalleled stargazing (from shielded observatories).
# 6.  **Culture:** A unique "Lunarian" culture emerges, blending elements from countless Earth nations, unified by a pioneering spirit, resilience, and a shared vision for humanity's future in space. Art, music, and entertainment often reflect the lunar environment and the challenges of space colonization.
# 7.  **Challenges:** Residents must contend with the psychological effects of isolation, confinement, and the constant awareness of their fragile existence. Robust mental health support, vibrant community events, and easy access to "green spaces" are crucial.
#
# ---
#
# ### IV. Future & Significance
#
# Luna City is more than just a settlement; it's a symbol. It represents:
#
# *   **Humanity's Reach:** Proof that we can thrive beyond our home planet.
# *   **A Stepping Stone:** The crucial first permanent off-world colony, paving the way for Mars, asteroid mining, and deeper space exploration.
# *   **A New Frontier:** A place for innovation, scientific discovery, and the evolution of human society in a truly alien environment.
# *   **A "Plan B":** A potential refuge or resource hub for humanity in the face of terrestrial catastrophes.
#
# In essence, Luna City is a marvel of engineering, a crucible of international cooperation, and a vibrant, living testament to the indomitable spirit of humanity to explore, settle, and build a future among the stars.
