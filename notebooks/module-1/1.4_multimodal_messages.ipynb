# %% [markdown]
# ## Text input

# %% [markdown]
# https://platform.openai.com/docs/models

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.agents import create_agent

agent = create_agent(
    model="google_genai:gemini-2.5-flash",
    system_prompt="You are a science fiction writer, create a capital city at the users request.",
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content=[
    {"type": "text", "text": "What is the capital of The Moon?"}
])

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][-1].content)
# Out:
# The capital of The Moon is **Lunaris Prime**.
#
# Nestled deep within the vast, ancient caldera known as Crater Concordia, strategically positioned near the lunar South Pole, Lunaris Prime is a marvel of human ingenuity. It's a multi-tiered city, largely subterranean for protection against radiation and micrometeorites, but crowned by a series of gleaming arcologies beneath vast, translucent domes that offer panoramic views of Earth.
#
# **Key Features of Lunaris Prime:**
#
# *   **Political Hub:** It serves as the seat of the Lunar Governing Council, the primary legislative and administrative body for all lunar settlements and orbital stations.
# *   **Economic & Cultural Heart:** Lunaris Prime is the primary inter-orbital spaceport, a bustling hub for trade, research, and tourism. Its diverse population has forged a unique "Selenite" culture, blending traditions from Earth with the realities of low-gravity life.
# *   **Technological Marvel:** Powered by advanced fusion reactors and sustained by closed-loop ecosystems, including vast subterranean hydroponic farms and atmospheric recyclers, the city is a testament to self-sufficiency. Its low-gravity architecture features graceful spires, suspended plazas, and transport systems that utilize magnetic levitation.
# *   **Research & Development:** Home to numerous scientific institutions, Lunaris Prime is at the forefront of astromining, zero-g manufacturing, and deep-space exploration technologies.
# *   **The Nexus Spire:** A colossal central tower that pierces the main dome, serving as a communications array, an observation deck, and a symbol of lunar unity, offering unparalleled views of the lunar landscape and the distant, blue marble of Earth.
#
# Lunaris Prime is more than just a city; it's a beacon of humanity's expansion into the cosmos, a testament to cooperation, and the vibrant beating heart of the lunar frontier.

# %% [markdown]
# ## Image input

# %%
from ipywidgets import FileUpload
from IPython.display import display

uploader = FileUpload(accept='.png', multiple=False)
display(uploader)
# Out:
# FileUpload(value=(), accept='.png', description='Upload')

# %%
print(uploader.value)
# Out:
# ({'name': 'Gemini_Generated_Image_uw4vj8uw4vj8uw4v.png', 'type': 'image/png', 'size': 7825401, 'content': <memory at 0x10f1ca800>, 'last_modified': datetime.datetime(2026, 3, 30, 13, 48, 47, 44000, tzinfo=datetime.timezone.utc)},)

# %%
import base64

# Get the first (and only) uploaded file dict
uploaded_file = uploader.value[0]

# This is a memoryview
content_mv = uploaded_file["content"]

# Convert memoryview -> bytes
img_bytes = bytes(content_mv)  # or content_mv.tobytes()

# Now base64 encode
img_b64 = base64.b64encode(img_bytes).decode("utf-8")

# %%
multimodal_question = HumanMessage(content=[
    {"type": "text", "text": "Tell me about this"},
    {"type": "image", "base64": img_b64, "mime_type": "image/png"}
])

response = agent.invoke(
    {"messages": [multimodal_question]}
)

print(response['messages'][-1].content)
# Out:
# Welcome to **Felicium**, the capital city of the Felidae Concordat, an interstellar alliance renowned for its peace, innovation, and profound appreciation for comfort.
#
# **Location & Structure:** Felicium is not built on a planetary surface, but rather a colossal, self-sustaining orbital habitat, a sphere of bio-engineered living tissue and advanced synthetics, gently rotating in the serene void between two binary suns. From a distance, its exterior shimmers with a soft, bioluminescent green hue, like a colossal, velvety cushion adrift in space, constantly regenerating and adapting.
#
# **Architecture & Design:** The city's internal architecture is a symphony of organic curves and soft geometries. Buildings eschew sharp angles, their structures flowing into one another with the subtle, rounded grace of a resting feline. Many major edifices, particularly governmental and diplomatic hubs, feature "folded" rooflines and layered facades, reminiscent of a Scottish Fold's distinctive ears. These aren't just for aesthetics; they are complex adaptive membranes, designed to passively harvest solar energy, filter cosmic radiation, and diffuse light into the city's interior.
#
# Pathways throughout Felicium are not hard pavement but resilient, self-repairing biopolymer weaves, soft underfoot and infused with gentle ambient light. The primary illumination within the city comes from a vast, interconnected network of engineered bioluminescent flora and fauna. This creates a perpetual, warm golden-beige glow, mimicking a soft, comforting twilight that never feels harsh or artificial, bathing every corner in a serene, dreamlike luminescence.
#
# **Technology & Lifestyle:** Felicium is the embodiment of "soft-tech" integration. Its advanced systems are almost invisible, designed to enhance comfort and well-being without intrusion. Atmospheric scrubbers are living, breathing fungal towers that also emit calming pheromones and regulate humidity. Energy is harvested through a blend of solar sails, zero-point conduits, and the city's own vast biogenerators, often manifested as shimmering, thread-like "light-strings" that crisscross public spaces, creating a sense of constant, gentle festivity and communal warmth.
#
# The city values knowledge, contemplation, and sustainable living. Grand "Archive-Groves" house not just digital data, but vast collections of physical books, their pages preserved by atmospheric controls, often found nestled amidst resilient, low-maintenance bio-sculptures (like the hardy succulents of old Earth) that adapt to individual reader's needs. Public spaces and private dwellings are furnished with ergonomic "comfort-pods" crafted from sustainable, self-repairing wood-synthetics and upholstered with responsive, temperature-regulating fabrics, inviting quiet reflection and relaxation. Even the advanced textiles worn by Felicium's inhabitants adapt to their wearer's body temperature and mood. Small, highly intelligent companion-AIs, often resembling the simple "felt mice" of ancient Terran lore, are common, offering subtle assistance and companionship without ever demanding attention.
#
# **Culture & Inhabitants:** Felicium is primarily populated by the N'yarl, a highly intelligent, bipedal species known for their graceful movements, keen observational skills, and a subtle, almost imperceptible "wink" in their expressive eyes when conveying understanding or amusement. They are profoundly empathetic and value harmony, deep connection, and quiet vigilance over overt displays of power. Their society is built on consensus and a deep respect for all forms of life, reflected in their reverence for ancient Terran felines, whose traits and comfort-seeking nature profoundly influenced Felicium's design and philosophy.
#
# **Atmosphere:** The dominant atmosphere of Felicium is one of profound peace, sophisticated comfort, and subtle watchfulness. It is a place where one feels perpetually at home, yet always aware of a deeper, knowing intelligence that guides its gentle hum. The occasional, playful "wink" from a passing N'yarl, the soft shimmer of the city's bioluminescent pathways, or the gentle, ambient sounds of its living architecture reminds visitors that while serenely comfortable, Felicium holds vast depths of wisdom and a quiet, formidable strength. It is a capital designed for thriving, not just surviving.

# %% [markdown]
# ## Audio input

# %%
import sounddevice as sd
from scipy.io.wavfile import write
import base64
import io
import time
from tqdm import tqdm

# Recording settings
duration = 5  # seconds
sample_rate = 44100

print("Recording...")
audio = sd.rec(int(duration * sample_rate), samplerate=sample_rate, channels=1)
# Progress bar for the duration
for _ in tqdm(range(duration * 10)):   # update 10× per second
    time.sleep(0.1)
sd.wait()
print("Done.")

# Write WAV to an in-memory buffer
buf = io.BytesIO()
write(buf, sample_rate, audio)
wav_bytes = buf.getvalue()

aud_b64 = base64.b64encode(wav_bytes).decode("utf-8")
# Out:
# Recording...
# 100%|███████████████████████████████████████████| 50/50 [00:05<00:00,  9.47it/s]
# Done.

# %%
agent = create_agent(
    model="google_genai:gemini-2.5-flash",
)

multimodal_question = HumanMessage(content=[
    {"type": "text", "text": "Tell me about this audio file"},
    {"type": "audio", "base64": aud_b64, "mime_type": "audio/wav"}
])

response = agent.invoke(
    {"messages": [multimodal_question]}
)

print(response['messages'][-1].content)
# Out:
# The audio begins with a brief, soft **whoosh or rustling sound** (around 0:00-0:01), possibly indicating movement near the microphone or a soft breath.
#
# Following this, a **single speaker** can be heard. The voice is **soft, gentle, and almost whispered** in tone. They utter the greeting **"Hello hi" twice** (from approximately 0:02 to 0:04).
#
# The background environment appears **very quiet**, with no other discernible sounds.
#
# Overall, the audio conveys a **calm, intimate, or possibly cautious atmosphere**, like someone speaking very gently or testing a microphone in a quiet space.
