# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ## No memory

# %%
from langchain.agents import create_agent


agent = create_agent(
  "google_genai:gemini-2.5-flash"
)
# Out:
# /Users/duaa/lca-lc-foundations/.venv/lib/python3.13/site-packages/langgraph/checkpoint/serde/encrypted.py:5: LangChainPendingDeprecationWarning: The default value of `allowed_objects` will change in a future version. Pass an explicit value (e.g., allowed_objects='messages' or allowed_objects='core') to suppress this warning.
#   from langgraph.checkpoint.serde.jsonplus import JsonPlusSerializer

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="Hello my name is Duaa and my favourite colour is green")

response = agent.invoke(
    {"messages": [question]} 
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content='Hello my name is Duaa and my favourite colour is green', additional_kwargs={}, response_metadata={}, id='3c867789-a8ac-4401-b79a-265486f39e92'),
#               AIMessage(content="Hello Duaa! It's lovely to meet you. Green is a wonderful color!", additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019e0f2f-8005-7a72-b546-b4072d40597d-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 13, 'output_tokens': 132, 'total_tokens': 145, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 114}})]}

# %%
question = HumanMessage(content="What's my favourite colour?")

response = agent.invoke(
    {"messages": [question]} 
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's my favourite colour?", additional_kwargs={}, response_metadata={}, id='772822c8-2e5b-4f50-bf05-ae072f935a5c'),
#               AIMessage(content="I can't possibly know your favorite color, as I don't have personal information about you! That's something only you know.\n\nWhat is it? I'd love to hear!", additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019e0f2f-a0df-7aa2-a1e1-ec0ba5a1bab0-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 8, 'output_tokens': 467, 'total_tokens': 475, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 426}})]}

# %% [markdown]
# ## Memory

# %%
from langgraph.checkpoint.memory import InMemorySaver  


agent = create_agent(
    model="google_genai:gemini-2.5-flash",
    checkpointer=InMemorySaver(),  
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="Hello my name is Dua and my favourite colour is green")
config = {"configurable": {"thread_id": "1"}}

response = agent.invoke(
    {"messages": [question]},
    config,  
)

# %%
pprint(response)
# Out:
# {'messages': [HumanMessage(content='Hello my name is Dua and my favourite colour is green', additional_kwargs={}, response_metadata={}, id='c9e5e5e0-cc16-480c-8933-d081f3fdc566'),
#               AIMessage(content="Hello Dua! It's lovely to meet you. Green is a wonderful color – so vibrant and refreshing!", additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019e0f30-0593-7353-976a-ab7693deba00-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 12, 'output_tokens': 408, 'total_tokens': 420, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 386}})]}

# %%
question = HumanMessage(content="What's my favourite colour?")

response = agent.invoke(
    {"messages": [question]},
    config,  
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content='Hello my name is Dua and my favourite colour is green', additional_kwargs={}, response_metadata={}, id='c9e5e5e0-cc16-480c-8933-d081f3fdc566'),
#               AIMessage(content="Hello Dua! It's lovely to meet you. Green is a wonderful color – so vibrant and refreshing!", additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019e0f30-0593-7353-976a-ab7693deba00-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 12, 'output_tokens': 408, 'total_tokens': 420, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 386}}),
#               HumanMessage(content="What's my favourite colour?", additional_kwargs={}, response_metadata={}, id='5987574b-44fb-41ec-a759-7c4a143dbaa7'),
#               AIMessage(content='Your favorite color is **green**!', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019e0f30-1dbe-7011-a75c-3b675043c005-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 43, 'output_tokens': 36, 'total_tokens': 79, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 28}})]}
