# %%
# !uv pip install -U langchain-google-genai
# Out:
# Using Python 3.13.13 environment at: /Users/duaa/lca-lc-foundations/.venv
# Resolved 39 packages in 1.55s
# Prepared 19 packages in 1.76s
# Uninstalled 18 packages in 157ms
# Installed 19 packages in 41ms
#  - anyio==4.12.1
#  + anyio==4.13.0
#  - certifi==2026.2.25
#  + certifi==2026.4.22
#  - charset-normalizer==3.4.5
#  + charset-normalizer==3.4.7
#  - cryptography==46.0.7
#  + cryptography==48.0.0
#  - google-auth==2.48.0
#  + google-auth==2.52.0
#  - google-genai==1.66.0
#  + google-genai==1.75.0
#  - idna==3.11
#  + idna==3.13
#  - jsonpointer==3.0.0
#  + jsonpointer==3.1.1
#  - langchain-core==1.3.0
#  + langchain-core==1.3.3
#  - langchain-google-genai==4.2.1
#  + langchain-google-genai==4.2.2
#  + langchain-protocol==0.0.15
#  - langsmith==0.7.31
#  + langsmith==0.8.3
#  - orjson==3.11.7
#  + orjson==3.11.9
#  - packaging==26.0
#  + packaging==26.2
#  - pydantic==2.12.5
#  + pydantic==2.13.4
#  - pydantic-core==2.41.5
#  + pydantic-core==2.46.4
#  - requests==2.33.0
# ...
